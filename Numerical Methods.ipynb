# %% [markdown]
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training

# %% [markdown]
# ## Data preparation

# %% [markdown]
# First thing I'll do is import any libraries I find necessary.

# %%
import numpy as np
import pandas as pd
from scipy import stats
import sklearn.linear_model
import sklearn.metrics
import sklearn.neighbors
import sklearn.preprocessing

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import xgboost as xgb
from catboost import CatBoostRegressor
import lightgbm as lgb

# %% [markdown]
# Next, I'll load the data and look to see what needs to be done to clean up the data and the best way to do so.

# %%
df = pd.read_csv('/datasets/car_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# Immediately, I noticed the columns have capital letters and are all one word. I will make all the columns lowercase and give spacing to the names that need it so it is easier to read.

# %%
df = df.rename(columns={'DateCrawled':'date_crawled', 'Price':'price', 'VehicleType':'vehicle_type',
                       'RegistrationYear':'registration_year', 'Gearbox':'gearbox', 'Power':'power', 'Model':'model',
                       'Mileage':'mileage', 'RegistrationMonth':'registration_month', 'FuelType':'fuel_type',
                       'Brand':'brand', 'NotRepaired':'not_repaired', 'DateCreated':'date_created',
                       'NumberOfPictures':'number_of_pictures', 'PostalCode':'postal_code', 'LastSeen':'last_seen'})

df.sample(10)
# Out:
#             date_crawled  price vehicle_type  registration_year gearbox  \
# 239202  21/03/2016 16:42   9900        wagon               2008    auto
# 245885  07/03/2016 19:40   9950        sedan               2007  manual
# 133213  31/03/2016 16:57   3300        small               2007  manual
# 224566  15/03/2016 12:51    450          NaN               2017  manual
# 161862  21/03/2016 11:47   6990        small               2012  manual
# 79788   27/03/2016 16:37      0          NaN               2016  manual
# 8570    16/03/2016 15:46  10000        wagon               2013  manual
# 100625  10/03/2016 07:54  16500  convertible               2005    auto
# 17259   30/03/2016 13:52    500        wagon               1997  manual
# 110163  27/03/2016 01:57   1890        small               1999  manual
#
#         power     model  mileage  registration_month fuel_type          brand  \
# 239202      0  c_klasse   150000                  10  gasoline  mercedes_benz
# 245885    177       5er   150000                   1  gasoline            bmw
# 133213     60        c2    60000                  11    petrol        citroen
# 224566    101      golf   150000                   0    petrol     volkswagen
# 161862     69     punto    30000                   5    petrol           fiat
# 79788      45      polo   125000                   4       NaN     volkswagen
# 8570      140    passat    40000                   6  gasoline     volkswagen
# 100625    300   mustang    90000                   3    petrol           ford
# 17259     101    vectra   150000                   6    petrol           opel
# 110163    110     ibiza   150000                   8  gasoline           seat
#
#        not_repaired      date_created  number_of_pictures  postal_code  \
# 239202           no  21/03/2016 00:00                   0        53332
# 245885           no  07/03/2016 00:00                   0        52445
# 133213           no  31/03/2016 00:00                   0        24594
# 224566          NaN  15/03/2016 00:00                   0        73733
# 161862           no  21/03/2016 00:00                   0        45527
# 79788            no  27/03/2016 00:00                   0        39606
# 8570             no  16/03/2016 00:00                   0        10115
# 100625           no  10/03/2016 00:00                   0        85391
# 17259           yes  30/03/2016 00:00                   0         6686
# 110163           no  27/03/2016 00:00                   0        38524
#
#                last_seen
# 239202  30/03/2016 03:16
# 245885  24/03/2016 17:15
# 133213  06/04/2016 10:46
# 224566  17/03/2016 07:46
# 161862  06/04/2016 05:45
# 79788   01/04/2016 16:45
# 8570    16/03/2016 15:46
# 100625  26/03/2016 10:17
# 17259   05/04/2016 01:46
# 110163  07/04/2016 04:16

# %% [markdown]
# Since this is such a large dataset, I feel comfortable droping any rows with NaN values since I do not think it will heavily affect the results of the models.

# %%
df = df.dropna()

# %% [markdown]
# Next, I will use the Label Encoder to change the object datatypes into integers that represent unique categories.

# %%
categorical_features = df[['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']]

label_encoder = LabelEncoder()

# This will iterate over each categorical column and encode the values
for column in categorical_features.columns:
    df[column] = label_encoder.fit_transform(df[column].astype(str))
    
print(df.head(10))
# Out:
#         date_crawled  price  vehicle_type  registration_year  gearbox  power  \
# 3   17/03/2016 16:54   1500             5               2001        1     75
# 4   31/03/2016 17:25   3600             5               2008        1     69
# 5   04/04/2016 17:36    650             4               1995        1    102
# 6   01/04/2016 20:48   2200             1               2004        1    109
# 7   21/03/2016 18:54      0             4               1980        1     50
# 10  26/03/2016 19:54   2000             4               2004        1    105
# 11  07/04/2016 10:06   2799             7               2005        1    140
# 14  21/03/2016 12:57  17999             6               2011        1    190
# 17  20/03/2016 10:25   1750             5               2004        0     75
# 18  23/03/2016 15:48   7550             0               2007        1    136
#
#     model  mileage  registration_month  fuel_type  brand  not_repaired  \
# 3     116   150000                   6          6     37             0
# 4     101    90000                   7          2     31             0
# 5      11   150000                  10          6      2             1
# 6       8   150000                   8          6     25             0
# 7     166    40000                   7          6     37             0
# 10     10   150000                  12          6     19             0
# 11    170   150000                  12          2     37             1
# 14    159    70000                   3          2     23             0
# 17    226   150000                   2          6     27             0
# 18     60   150000                   6          2     10             0
#
#         date_created  number_of_pictures  postal_code         last_seen
# 3   17/03/2016 00:00                   0        91074  17/03/2016 17:40
# 4   31/03/2016 00:00                   0        60437  06/04/2016 10:17
# 5   04/04/2016 00:00                   0        33775  06/04/2016 19:17
# 6   01/04/2016 00:00                   0        67112  05/04/2016 18:18
# 7   21/03/2016 00:00                   0        19348  25/03/2016 16:47
# 10  26/03/2016 00:00                   0        96224  06/04/2016 10:45
# 11  07/04/2016 00:00                   0        57290  07/04/2016 10:25
# 14  21/03/2016 00:00                   0         4177  06/04/2016 07:45
# 17  20/03/2016 00:00                   0        65599  06/04/2016 13:16
# 18  23/03/2016 00:00                   0        88361  05/04/2016 18:45

# %%
print(df.describe())
df.drop('number_of_pictures', axis=1, inplace=True)
df.info()
# Out:
#                price   vehicle_type  registration_year        gearbox  \
# count  245814.000000  245814.000000      245814.000000  245814.000000
# mean     5125.346717       4.253525        2002.918699       0.792209
# std      4717.948673       2.131782           6.163765       0.405727
# min         0.000000       0.000000        1910.000000       0.000000
# 25%      1499.000000       4.000000        1999.000000       1.000000
# 50%      3500.000000       4.000000        2003.000000       1.000000
# 75%      7500.000000       5.000000        2007.000000       1.000000
# max     20000.000000       7.000000        2018.000000       1.000000
#
#                power          model        mileage  registration_month  \
# count  245814.000000  245814.000000  245814.000000       245814.000000
# mean      119.970884     108.049651  127296.716216            6.179701
# std       139.387116      70.990730   37078.820368            3.479519
# min         0.000000       0.000000    5000.000000            0.000000
# 25%        75.000000      42.000000  125000.000000            3.000000
# 50%       110.000000     106.000000  150000.000000            6.000000
# 75%       150.000000     166.000000  150000.000000            9.000000
# max     20000.000000     248.000000  150000.000000           12.000000
#
#            fuel_type          brand   not_repaired  number_of_pictures  \
# count  245814.000000  245814.000000  245814.000000            245814.0
# mean        4.675560      20.223421       0.113167                 0.0
# std         1.870889      13.036363       0.316797                 0.0
# min         0.000000       0.000000       0.000000                 0.0
# 25%         2.000000       9.000000       0.000000                 0.0
# 50%         6.000000      23.000000       0.000000                 0.0
# 75%         6.000000      32.000000       0.000000                 0.0
# max         6.000000      38.000000       1.000000                 0.0
#
#          postal_code
# count  245814.000000
# mean    51463.186002
# std     25838.058847
# min      1067.000000
# 25%     30966.000000
# 50%     50769.000000
# 75%     72379.000000
# max     99998.000000
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245814 entries, 3 to 354367
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        245814 non-null  object
#  1   price               245814 non-null  int64
#  2   vehicle_type        245814 non-null  int64
#  3   registration_year   245814 non-null  int64
#  4   gearbox             245814 non-null  int64
#  5   power               245814 non-null  int64
#  6   model               245814 non-null  int64
#  7   mileage             245814 non-null  int64
#  8   registration_month  245814 non-null  int64
#  9   fuel_type           245814 non-null  int64
#  10  brand               245814 non-null  int64
#  11  not_repaired        245814 non-null  int64
#  12  date_created        245814 non-null  object
#  13  postal_code         245814 non-null  int64
#  14  last_seen           245814 non-null  object
# dtypes: int64(12), object(3)
# memory usage: 30.0+ MB

# %% [markdown]
# Upon further EDA, I have discovered that the 'number_of_pictures' column is filled entirely of zeros. Since this is clearly an error, I have dropped the column completely.

# %% [markdown]
# We can now see that the dataframe columns that had object datatypes now contain integers that represent unique categories.
#
# I will drop the required columns to run the models proficiently.

# %%
drop_columns = ['date_crawled', 'date_created', 'last_seen', 'price']
features = df.drop(drop_columns, axis=1)
target = df['price']

features_train_val, features_test, target_train_val, target_test = train_test_split(features,
                                                                                    target,
                                                                                    test_size=0.2,
                                                                                    random_state=12345)

features_train, features_valid, target_train, target_valid = train_test_split(features_train_val,
                                                                              target_train_val,
                                                                              test_size=0.25,
                                                                              random_state=12345)

# %% [markdown]
# Since the dataset has a potential for large numbers, I decided to scale the feature data. Scaling the feature data helps make the model training process more reliable.

# %%
scaler = StandardScaler()
scaler.fit(features_train)

features_train = scaler.transform(features_train)
features_valid = scaler.transform(features_valid)

# %% [markdown]
# ## Model training

# %%
# %%time

lr = LinearRegression()
lr.fit(features_train, target_train)
predictions_lr = lr.predict(features_valid)

result_lr = mean_squared_error(target_valid, predictions_lr, squared=False)
print("RMSE of the Linear Regression model on the validation set:", result_lr)
# Out:
# RMSE of the Linear Regression model on the validation set: 3343.2026497566317
# CPU times: user 48.1 ms, sys: 12.1 ms, total: 60.2 ms
# Wall time: 42.9 ms

# %%
class SGDLinearRegression:
    def __init__(self, step_size, epochs, batch_size):
        self.step_size = step_size
        self.epochs = epochs
        self.batch_size = batch_size
        self.w = None
        
    def fit(self, train_features, train_target):
        X = np.concatenate(
            (np.ones((train_features.shape[0], 1)), train_features), axis=1
        )
        y = train_target
        w = np.zeros(X.shape[1])
        
        for _ in range(self.epochs):
            batches_count = X.shape[0] // self.batch_size
            for i in range(batches_count):
                begin = i * self.batch_size
                end = (i + 1) * self.batch_size
                X_batch = X[begin:end, :]
                y_batch = y[begin:end]
                
                gradient = 2 * X_batch.T.dot(X_batch.dot(w) - y_batch) / X_batch.shape[0]
                
                w -= self.step_size * gradient
        
        self.w = w

# %%
# %%time

sgd_lr = SGDLinearRegression(step_size=0.01, epochs=100, batch_size=32)
sgd_lr.fit(features_train, target_train)

predictions_sgd = np.dot(np.concatenate((np.ones((features_valid.shape[0], 1)), features_valid), axis=1), sgd_lr.w)
rmse_sgd = mean_squared_error(target_valid, predictions_sgd, squared=False)

print("RMSE of the SGD Linear Regression model on the validaiton set:", rmse_sgd)
# Out:
# RMSE of the SGD Linear Regression model on the validaiton set: 3655.542951267383
# CPU times: user 2min 11s, sys: 1.7 s, total: 2min 13s
# Wall time: 2min 13s

# %%
# %%time

rfr = RandomForestRegressor(n_estimators=100, random_state=12345)
rfr.fit(features_train, target_train)
predictions_rfr = rfr.predict(features_valid)

result_rfr = mean_squared_error(target_valid, predictions_rfr, squared=False)
print("RMSE of the Random Forest Regression model on the validation set:", result_rfr)
# Out:
# RMSE of the Random Forest Regression model on the validation set: 1635.4025039604942
# CPU times: user 1min 26s, sys: 467 ms, total: 1min 27s
# Wall time: 1min 27s

# %%
# %%time

dtr = DecisionTreeRegressor(random_state=12345)
dtr.fit(features_train, target_train)
predictions_dtr = dtr.predict(features_valid)

result_dtr = mean_squared_error(target_valid, predictions_dtr, squared=False)
print("RMSE of the Decision Tree Regression model on the validation set:", result_dtr)
# Out:
# RMSE of the Decision Tree Regression model on the validation set: 2237.179300431031
# CPU times: user 1.35 s, sys: 0 ns, total: 1.35 s
# Wall time: 1.34 s

# %%
# %%time

dtrain = xgb.DMatrix(features_train, label=target_train)
dvalid = xgb.DMatrix(features_valid, label=target_valid)

params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse'
}

num_rounds = 100
xgb_model = xgb.train(params, dtrain, num_rounds)

predictions_xgb = xgb_model.predict(dvalid)

rmse_xgb = mean_squared_error(target_valid, predictions_xgb, squared=False)
print('RMSE of the XGBoost Regressor model on the validation set:', rmse_xgb)
# Out:
# RMSE of the XGBoost Regressor model on the validation set: 1650.0206482819442
# CPU times: user 27.3 s, sys: 109 ms, total: 27.4 s
# Wall time: 27.6 s

# %%
# %%time

lgbm_train = lgb.Dataset(features_train, label=target_train)
lgbm_valid = lgb.Dataset(features_valid, label=target_valid)

params = {
    'objective': 'regression',
    'metric': 'rmse'
}

num_rounds = 100
lgb_model = lgb.train(params, lgbm_train, num_rounds, valid_sets=[lgbm_valid], early_stopping_rounds=10)

predictions_lgb = lgb_model.predict(features_valid, num_iteration=lgb_model.best_iteration)
rmse_lgb = mean_squared_error(target_valid, predictions_lgb, squared=False)

print('RMSE of the LightGBM model on the validation set:', rmse_lgb)
# Out:
# /opt/conda/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002310 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 919
# [LightGBM] [Info] Number of data points in the train set: 147488, number of used features: 11
# [LightGBM] [Info] Start training from score 5135.456844
# [1]	valid_0's rmse: 4389.27
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's rmse: 4087.44
# [3]	valid_0's rmse: 3823.47
# [4]	valid_0's rmse: 3592.38
# [5]	valid_0's rmse: 3390.92
# [6]	valid_0's rmse: 3211.58
# [7]	valid_0's rmse: 3057.56
# [8]	valid_0's rmse: 2923.96
# [9]	valid_0's rmse: 2805.59
# [10]	valid_0's rmse: 2701.31
# [11]	valid_0's rmse: 2612.4
# [12]	valid_0's rmse: 2534.39
# [13]	valid_0's rmse: 2464.26
# [14]	valid_0's rmse: 2404.27
# [15]	valid_0's rmse: 2349.22
# [16]	valid_0's rmse: 2302.96
# [17]	valid_0's rmse: 2259.83
# [18]	valid_0's rmse: 2221.62
# [19]	valid_0's rmse: 2186.32
# [20]	valid_0's rmse: 2156.54
# [21]	valid_0's rmse: 2128.66
# [22]	valid_0's rmse: 2098.02
# [23]	valid_0's rmse: 2076.13
# [24]	valid_0's rmse: 2054.4
# [25]	valid_0's rmse: 2035.4
# [26]	valid_0's rmse: 2020.03
# [27]	valid_0's rmse: 2001.91
# [28]	valid_0's rmse: 1986.69
# [29]	valid_0's rmse: 1970.71
# [30]	valid_0's rmse: 1957.67
# [31]	valid_0's rmse: 1945.63
# [32]	valid_0's rmse: 1936.31
# [33]	valid_0's rmse: 1925.45
# [34]	valid_0's rmse: 1916.32
# [35]	valid_0's rmse: 1907.48
# [36]	valid_0's rmse: 1897.98
# [37]	valid_0's rmse: 1891.25
# [38]	valid_0's rmse: 1882.37
# [39]	valid_0's rmse: 1875.73
# [40]	valid_0's rmse: 1869.71
# [41]	valid_0's rmse: 1863.37
# [42]	valid_0's rmse: 1857.02
# [43]	valid_0's rmse: 1851.81
# [44]	valid_0's rmse: 1848.11
# [45]	valid_0's rmse: 1842.94
# [46]	valid_0's rmse: 1840.22
# [47]	valid_0's rmse: 1835.99
# [48]	valid_0's rmse: 1831.88
# [49]	valid_0's rmse: 1828.23
# [50]	valid_0's rmse: 1823.99
# [51]	valid_0's rmse: 1819.65
# [52]	valid_0's rmse: 1817.47
# [53]	valid_0's rmse: 1813.28
# [54]	valid_0's rmse: 1809.69
# [55]	valid_0's rmse: 1805.5
# [56]	valid_0's rmse: 1804.05
# [57]	valid_0's rmse: 1800.19
# [58]	valid_0's rmse: 1798.46
# [59]	valid_0's rmse: 1795.05
# [60]	valid_0's rmse: 1792.64
# [61]	valid_0's rmse: 1790.62
# [62]	valid_0's rmse: 1788.03
# [63]	valid_0's rmse: 1785.55
# [64]	valid_0's rmse: 1782.7
# [65]	valid_0's rmse: 1780.92
# [66]	valid_0's rmse: 1779.51
# [67]	valid_0's rmse: 1777.9
# [68]	valid_0's rmse: 1774.89
# [69]	valid_0's rmse: 1772.71
# [70]	valid_0's rmse: 1771.61
# [71]	valid_0's rmse: 1769.75
# [72]	valid_0's rmse: 1768.73
# [73]	valid_0's rmse: 1767.44
# [74]	valid_0's rmse: 1766.19
# [75]	valid_0's rmse: 1764.07
# [76]	valid_0's rmse: 1762.97
# [77]	valid_0's rmse: 1760.09
# [78]	valid_0's rmse: 1757.68
# [79]	valid_0's rmse: 1757.04
# [80]	valid_0's rmse: 1754.93
# [81]	valid_0's rmse: 1754.33
# [82]	valid_0's rmse: 1752.13
# [83]	valid_0's rmse: 1750.71
# [84]	valid_0's rmse: 1749.23
# [85]	valid_0's rmse: 1747.66
# [86]	valid_0's rmse: 1745.66
# [87]	valid_0's rmse: 1745.33
# [88]	valid_0's rmse: 1744.11
# [89]	valid_0's rmse: 1742.44
# [90]	valid_0's rmse: 1741.07
# [91]	valid_0's rmse: 1739.68
# [92]	valid_0's rmse: 1738.78
# [93]	valid_0's rmse: 1738.24
# [94]	valid_0's rmse: 1737.28
# [95]	valid_0's rmse: 1735.83
# [96]	valid_0's rmse: 1734.83
# [97]	valid_0's rmse: 1734.08
# [98]	valid_0's rmse: 1732.5
# [99]	valid_0's rmse: 1731.42
# [100]	valid_0's rmse: 1730.25
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 1730.25
# RMSE of the LightGBM model on the validation set: 1730.2493937646727
# CPU times: user 4.1 s, sys: 44.8 ms, total: 4.14 s
# Wall time: 4.14 s

# %%
# %%time

catboost_model = CatBoostRegressor(iterations=100,
                                  loss_function='RMSE',
                                  eval_metric='RMSE',
                                  random_seed=12345)

catboost_model.fit(features_train, target_train, eval_set=(features_valid, target_valid), early_stopping_rounds=10, verbose=False)

predictions_catboost = catboost_model.predict(features_valid)
rmse_catboost = mean_squared_error(target_valid, predictions_catboost, squared=False)

print("RMSE of the CatBoost model on the validation set:", rmse_catboost)
# Out:
# RMSE of the CatBoost model on the validation set: 1708.274099598683
# CPU times: user 3.13 s, sys: 32 ms, total: 3.16 s
# Wall time: 3.37 s

# %% [markdown]
# Now, I'm going to use the test set on the Random Forest model and the CatBoost model. I'm choosing these two because the Random Forest had the best result, and the CatBoost had the second best result and was significantly faster.

# %%
features_test_scaled = scaler.transform(features_test)

predictions_rfr_test = rfr.predict(features_test)
rmse_rfr_test = mean_squared_error(target_test, predictions_rfr_test, squared=False)
print("RMSE of the Random Forest Regression model on the test set:", rmse_rfr_test)
# Out:
# RMSE of the Random Forest Regression model on the test set: 5209.36487182959

# %%
predictions_catboost_test = catboost_model.predict(features_test_scaled)
rmse_catboost_test = mean_squared_error(target_test, predictions_catboost_test, squared=False)
print("RMSE of the CatBoost model on the test set:", rmse_catboost_test)
# Out:
# RMSE of the CatBoost model on the test set: 1708.2436239697508

# %% [markdown]
# Given that the CatBoost model performed significantly better than the Random Forest model on the test set, that would be the model that Rusty Bargain should consider using.

# %%
# %%time

rf_cv_scores = cross_val_score(rfr, features, target, cv=5)
rf_final_score = sum(rf_cv_scores) / len(rf_cv_scores)

print("Average Random Forest Regression evaluation score:", rf_final_score)

# %%
# %%time

catboost_cv_scores = cross_val_score(catboost_model, features, target, cv=5)
catboost_final_score = sum(catboost_cv_scores) / len(catboost_cv_scores)

print("Average CatBoost evaluation score:", catboost_final_score)
# Out:
# Learning rate set to 0.5
# 0:	learn: 3313.7494737	total: 46.8ms	remaining: 4.63s
# 1:	learn: 2670.9990775	total: 93ms	remaining: 4.56s
# 2:	learn: 2408.0628671	total: 133ms	remaining: 4.31s
# 3:	learn: 2282.4673045	total: 175ms	remaining: 4.19s
# 4:	learn: 2203.5555298	total: 219ms	remaining: 4.17s
# 5:	learn: 2152.3403951	total: 257ms	remaining: 4.03s
# 6:	learn: 2089.4259336	total: 307ms	remaining: 4.08s
# 7:	learn: 2063.4313712	total: 344ms	remaining: 3.96s
# 8:	learn: 2040.7232232	total: 389ms	remaining: 3.93s
# 9:	learn: 2005.5048544	total: 439ms	remaining: 3.95s
# 10:	learn: 1983.2334146	total: 482ms	remaining: 3.9s
# 11:	learn: 1969.3922876	total: 527ms	remaining: 3.87s
# 12:	learn: 1952.7958608	total: 565ms	remaining: 3.78s
# 13:	learn: 1940.3790506	total: 612ms	remaining: 3.76s
# 14:	learn: 1930.4793586	total: 647ms	remaining: 3.67s
# 15:	learn: 1921.6271705	total: 688ms	remaining: 3.61s
# 16:	learn: 1914.0717298	total: 728ms	remaining: 3.55s
# 17:	learn: 1898.8272488	total: 770ms	remaining: 3.51s
# 18:	learn: 1892.8760920	total: 806ms	remaining: 3.43s
# 19:	learn: 1883.3052357	total: 849ms	remaining: 3.39s
# 20:	learn: 1872.7821558	total: 890ms	remaining: 3.35s
# 21:	learn: 1863.8939767	total: 934ms	remaining: 3.31s
# 22:	learn: 1856.7919767	total: 972ms	remaining: 3.25s
# 23:	learn: 1851.7377922	total: 1.01s	remaining: 3.21s
# 24:	learn: 1844.2334970	total: 1.05s	remaining: 3.16s
# 25:	learn: 1836.1536932	total: 1.11s	remaining: 3.15s
# 26:	learn: 1831.5486428	total: 1.15s	remaining: 3.1s
# 27:	learn: 1824.0089502	total: 1.19s	remaining: 3.05s
# 28:	learn: 1818.9530726	total: 1.23s	remaining: 3.01s
# 29:	learn: 1815.2784132	total: 1.28s	remaining: 2.98s
# 30:	learn: 1808.8639411	total: 1.34s	remaining: 2.98s
# 31:	learn: 1804.3836232	total: 1.38s	remaining: 2.93s
# 32:	learn: 1802.2220001	total: 1.42s	remaining: 2.88s
# 33:	learn: 1797.7067157	total: 1.46s	remaining: 2.84s
# 34:	learn: 1795.3090144	total: 1.51s	remaining: 2.8s
# 35:	learn: 1791.7772867	total: 1.55s	remaining: 2.76s
# 36:	learn: 1789.7251407	total: 1.59s	remaining: 2.71s
# 37:	learn: 1786.6325445	total: 1.64s	remaining: 2.67s
# 38:	learn: 1784.2519617	total: 1.68s	remaining: 2.62s
# 39:	learn: 1779.9104028	total: 1.73s	remaining: 2.59s
# 40:	learn: 1776.1638063	total: 1.76s	remaining: 2.53s
# 41:	learn: 1773.8690519	total: 1.8s	remaining: 2.48s
# 42:	learn: 1770.9067423	total: 1.83s	remaining: 2.43s
# 43:	learn: 1767.6307826	total: 1.87s	remaining: 2.39s
# 44:	learn: 1763.0309238	total: 1.93s	remaining: 2.36s
# 45:	learn: 1760.4437662	total: 1.97s	remaining: 2.31s
# 46:	learn: 1756.0104357	total: 2.02s	remaining: 2.27s
# 47:	learn: 1753.7237274	total: 2.06s	remaining: 2.23s
# 48:	learn: 1750.4007517	total: 2.1s	remaining: 2.19s
# 49:	learn: 1747.4106630	total: 2.15s	remaining: 2.15s
# 50:	learn: 1745.1083771	total: 2.19s	remaining: 2.11s
# 51:	learn: 1742.7829194	total: 2.24s	remaining: 2.06s
# 52:	learn: 1739.0543138	total: 2.28s	remaining: 2.02s
# 53:	learn: 1737.8620596	total: 2.32s	remaining: 1.97s
# 54:	learn: 1736.0919976	total: 2.36s	remaining: 1.93s
# 55:	learn: 1733.9719648	total: 2.4s	remaining: 1.89s
# 56:	learn: 1729.9442812	total: 2.45s	remaining: 1.85s
# 57:	learn: 1727.5898705	total: 2.49s	remaining: 1.8s
# 58:	learn: 1725.1695477	total: 2.53s	remaining: 1.76s
# 59:	learn: 1723.0784960	total: 2.58s	remaining: 1.72s
# 60:	learn: 1721.3320667	total: 2.62s	remaining: 1.68s
# 61:	learn: 1718.9216873	total: 2.67s	remaining: 1.64s
# 62:	learn: 1717.2190035	total: 2.71s	remaining: 1.59s
# 63:	learn: 1715.7536899	total: 2.76s	remaining: 1.55s
# 64:	learn: 1713.0480545	total: 2.82s	remaining: 1.52s
# 65:	learn: 1711.8524380	total: 2.86s	remaining: 1.47s
# 66:	learn: 1710.1872138	total: 2.9s	remaining: 1.43s
# 67:	learn: 1708.6370523	total: 2.94s	remaining: 1.38s
# 68:	learn: 1706.5213877	total: 2.98s	remaining: 1.34s
# 69:	learn: 1704.9624498	total: 3.03s	remaining: 1.3s
# 70:	learn: 1702.8114423	total: 3.08s	remaining: 1.26s
# 71:	learn: 1701.2151508	total: 3.12s	remaining: 1.21s
# 72:	learn: 1700.3305743	total: 3.16s	remaining: 1.17s
# 73:	learn: 1698.6812822	total: 3.21s	remaining: 1.13s
# 74:	learn: 1697.0885470	total: 3.25s	remaining: 1.08s
# 75:	learn: 1694.9387413	total: 3.29s	remaining: 1.04s
# 76:	learn: 1693.3726572	total: 3.33s	remaining: 995ms
# 77:	learn: 1692.0667591	total: 3.38s	remaining: 952ms
# 78:	learn: 1690.7313762	total: 3.41s	remaining: 906ms
# 79:	learn: 1689.3942973	total: 3.46s	remaining: 865ms
# 80:	learn: 1686.9230920	total: 3.51s	remaining: 824ms
# 81:	learn: 1684.9985073	total: 3.56s	remaining: 782ms
# 82:	learn: 1683.7988717	total: 3.6s	remaining: 737ms
# 83:	learn: 1682.3992394	total: 3.64s	remaining: 693ms
# 84:	learn: 1681.0018404	total: 3.69s	remaining: 651ms
# 85:	learn: 1679.4749004	total: 3.72s	remaining: 606ms
# 86:	learn: 1677.7251548	total: 3.77s	remaining: 563ms
# 87:	learn: 1677.0188561	total: 3.81s	remaining: 519ms
# 88:	learn: 1676.0695432	total: 3.85s	remaining: 475ms
# 89:	learn: 1675.1922911	total: 3.89s	remaining: 432ms
# 90:	learn: 1673.6462171	total: 3.93s	remaining: 389ms
# 91:	learn: 1672.1547812	total: 3.96s	remaining: 345ms
# 92:	learn: 1669.1477241	total: 4.01s	remaining: 302ms
# 93:	learn: 1667.8112258	total: 4.06s	remaining: 259ms
# 94:	learn: 1667.1577065	total: 4.1s	remaining: 216ms
# 95:	learn: 1665.6318995	total: 4.14s	remaining: 172ms
# 96:	learn: 1664.3157949	total: 4.18s	remaining: 129ms
# 97:	learn: 1662.4708027	total: 4.23s	remaining: 86.4ms
# 98:	learn: 1661.5478609	total: 4.28s	remaining: 43.3ms
# 99:	learn: 1660.2182082	total: 4.32s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3282.2833550	total: 46.4ms	remaining: 4.59s
# 1:	learn: 2662.7570627	total: 87.1ms	remaining: 4.27s
# 2:	learn: 2384.6775596	total: 136ms	remaining: 4.4s
# 3:	learn: 2258.4055824	total: 184ms	remaining: 4.42s
# 4:	learn: 2181.2489026	total: 227ms	remaining: 4.32s
# 5:	learn: 2127.0194839	total: 272ms	remaining: 4.27s
# 6:	learn: 2094.1121600	total: 316ms	remaining: 4.2s
# 7:	learn: 2047.6847131	total: 363ms	remaining: 4.18s
# 8:	learn: 2008.1843066	total: 417ms	remaining: 4.21s
# 9:	learn: 1991.8709832	total: 465ms	remaining: 4.18s
# 10:	learn: 1974.0485650	total: 515ms	remaining: 4.16s
# 11:	learn: 1958.8952161	total: 562ms	remaining: 4.12s
# 12:	learn: 1942.0707337	total: 616ms	remaining: 4.12s
# 13:	learn: 1925.2819677	total: 672ms	remaining: 4.13s
# 14:	learn: 1916.4790601	total: 708ms	remaining: 4.01s
# 15:	learn: 1908.0504582	total: 749ms	remaining: 3.93s
# 16:	learn: 1893.9367109	total: 793ms	remaining: 3.87s
# 17:	learn: 1888.7128503	total: 829ms	remaining: 3.77s
# 18:	learn: 1878.3184235	total: 875ms	remaining: 3.73s
# 19:	learn: 1874.4301804	total: 912ms	remaining: 3.65s
# 20:	learn: 1864.8330481	total: 957ms	remaining: 3.6s
# 21:	learn: 1856.5789527	total: 1s	remaining: 3.56s
# 22:	learn: 1842.7062401	total: 1.05s	remaining: 3.52s
# 23:	learn: 1836.7406811	total: 1.09s	remaining: 3.46s
# 24:	learn: 1831.0461434	total: 1.13s	remaining: 3.4s
# 25:	learn: 1825.7704669	total: 1.17s	remaining: 3.33s
# 26:	learn: 1819.8420189	total: 1.22s	remaining: 3.29s
# 27:	learn: 1817.3382966	total: 1.27s	remaining: 3.26s
# 28:	learn: 1813.2083259	total: 1.32s	remaining: 3.22s
# 29:	learn: 1807.8319223	total: 1.36s	remaining: 3.19s
# 30:	learn: 1801.9083049	total: 1.41s	remaining: 3.14s
# 31:	learn: 1797.5327710	total: 1.45s	remaining: 3.08s
# 32:	learn: 1792.8152286	total: 1.5s	remaining: 3.05s
# 33:	learn: 1787.8792613	total: 1.58s	remaining: 3.06s
# 34:	learn: 1784.3650209	total: 1.65s	remaining: 3.07s
# 35:	learn: 1782.2711601	total: 1.72s	remaining: 3.06s
# 36:	learn: 1777.7974853	total: 1.8s	remaining: 3.06s
# 37:	learn: 1775.3295712	total: 1.85s	remaining: 3.02s
# 38:	learn: 1772.1321431	total: 1.9s	remaining: 2.96s
# 39:	learn: 1767.5180360	total: 1.93s	remaining: 2.9s
# 40:	learn: 1764.3539087	total: 1.98s	remaining: 2.85s
# 41:	learn: 1761.8185627	total: 2.02s	remaining: 2.79s
# 42:	learn: 1758.0563049	total: 2.06s	remaining: 2.73s
# 43:	learn: 1754.6000910	total: 2.1s	remaining: 2.67s
# 44:	learn: 1752.7499181	total: 2.15s	remaining: 2.63s
# 45:	learn: 1749.8375120	total: 2.2s	remaining: 2.58s
# 46:	learn: 1747.3356364	total: 2.24s	remaining: 2.53s
# 47:	learn: 1745.6724485	total: 2.28s	remaining: 2.47s
# 48:	learn: 1741.6728505	total: 2.33s	remaining: 2.43s
# 49:	learn: 1739.2907510	total: 2.38s	remaining: 2.38s
# 50:	learn: 1735.6756729	total: 2.42s	remaining: 2.33s
# 51:	learn: 1733.5023602	total: 2.46s	remaining: 2.27s
# 52:	learn: 1730.0526316	total: 2.51s	remaining: 2.23s
# 53:	learn: 1727.4620008	total: 2.55s	remaining: 2.17s
# 54:	learn: 1726.2408997	total: 2.59s	remaining: 2.12s
# 55:	learn: 1724.2035329	total: 2.63s	remaining: 2.07s
# 56:	learn: 1722.2403569	total: 2.68s	remaining: 2.02s
# 57:	learn: 1721.2111642	total: 2.72s	remaining: 1.97s
# 58:	learn: 1719.6766613	total: 2.77s	remaining: 1.92s
# 59:	learn: 1717.9443171	total: 2.82s	remaining: 1.88s
# 60:	learn: 1715.6153705	total: 2.87s	remaining: 1.83s
# 61:	learn: 1713.0717171	total: 2.92s	remaining: 1.79s
# 62:	learn: 1710.4474513	total: 2.96s	remaining: 1.74s
# 63:	learn: 1708.4285590	total: 3s	remaining: 1.69s
# 64:	learn: 1706.9213585	total: 3.04s	remaining: 1.63s
# 65:	learn: 1703.7524619	total: 3.09s	remaining: 1.59s
# 66:	learn: 1701.0132406	total: 3.13s	remaining: 1.54s
# 67:	learn: 1699.2552696	total: 3.17s	remaining: 1.49s
# 68:	learn: 1697.8342834	total: 3.21s	remaining: 1.44s
# 69:	learn: 1696.5500622	total: 3.25s	remaining: 1.39s
# 70:	learn: 1695.0041002	total: 3.29s	remaining: 1.34s
# 71:	learn: 1694.1784699	total: 3.33s	remaining: 1.29s
# 72:	learn: 1693.2165602	total: 3.37s	remaining: 1.24s
# 73:	learn: 1692.0986730	total: 3.4s	remaining: 1.2s
# 74:	learn: 1690.9028420	total: 3.44s	remaining: 1.15s
# 75:	learn: 1689.8199821	total: 3.48s	remaining: 1.1s
# 76:	learn: 1685.1174610	total: 3.54s	remaining: 1.06s
# 77:	learn: 1680.5752699	total: 3.6s	remaining: 1.01s
# 78:	learn: 1678.3916684	total: 3.64s	remaining: 969ms
# 79:	learn: 1676.7642273	total: 3.69s	remaining: 921ms
# 80:	learn: 1675.3853852	total: 3.72s	remaining: 874ms
# 81:	learn: 1673.9309916	total: 3.77s	remaining: 827ms
# 82:	learn: 1671.1733711	total: 3.81s	remaining: 781ms
# 83:	learn: 1670.1009258	total: 3.85s	remaining: 734ms
# 84:	learn: 1669.6408556	total: 3.89s	remaining: 687ms
# 85:	learn: 1668.4424778	total: 3.94s	remaining: 641ms
# 86:	learn: 1665.7704817	total: 3.99s	remaining: 596ms
# 87:	learn: 1664.2377269	total: 4.03s	remaining: 550ms
# 88:	learn: 1663.0025276	total: 4.08s	remaining: 504ms
# 89:	learn: 1661.4329862	total: 4.12s	remaining: 458ms
# 90:	learn: 1660.0834321	total: 4.17s	remaining: 413ms
# 91:	learn: 1657.9381079	total: 4.22s	remaining: 367ms
# 92:	learn: 1656.6166179	total: 4.26s	remaining: 321ms
# 93:	learn: 1654.3487498	total: 4.3s	remaining: 275ms
# 94:	learn: 1652.8875643	total: 4.35s	remaining: 229ms
# 95:	learn: 1651.7550033	total: 4.39s	remaining: 183ms
# 96:	learn: 1650.5860730	total: 4.44s	remaining: 137ms
# 97:	learn: 1649.0875994	total: 4.48s	remaining: 91.4ms
# 98:	learn: 1647.9566817	total: 4.52s	remaining: 45.7ms
# 99:	learn: 1646.2842697	total: 4.56s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3287.4087625	total: 46.9ms	remaining: 4.64s
# 1:	learn: 2665.8425951	total: 96.2ms	remaining: 4.71s
# 2:	learn: 2392.7372306	total: 145ms	remaining: 4.68s
# 3:	learn: 2265.5891001	total: 196ms	remaining: 4.71s
# 4:	learn: 2189.3387345	total: 241ms	remaining: 4.59s
# 5:	learn: 2129.1885026	total: 287ms	remaining: 4.5s
# 6:	learn: 2084.8265832	total: 338ms	remaining: 4.5s
# 7:	learn: 2054.3305446	total: 382ms	remaining: 4.39s
# 8:	learn: 2036.8523043	total: 421ms	remaining: 4.26s
# 9:	learn: 2008.0649097	total: 461ms	remaining: 4.15s
# 10:	learn: 1976.5565514	total: 512ms	remaining: 4.14s
# 11:	learn: 1956.7836111	total: 552ms	remaining: 4.05s
# 12:	learn: 1944.8570918	total: 593ms	remaining: 3.97s
# 13:	learn: 1929.8795189	total: 636ms	remaining: 3.91s
# 14:	learn: 1920.9429878	total: 672ms	remaining: 3.81s
# 15:	learn: 1912.0304031	total: 708ms	remaining: 3.71s
# 16:	learn: 1904.4010985	total: 747ms	remaining: 3.65s
# 17:	learn: 1893.3977215	total: 791ms	remaining: 3.6s
# 18:	learn: 1878.0302776	total: 837ms	remaining: 3.57s
# 19:	learn: 1869.2248701	total: 875ms	remaining: 3.5s
# 20:	learn: 1859.0248538	total: 917ms	remaining: 3.45s
# 21:	learn: 1851.1414017	total: 965ms	remaining: 3.42s
# 22:	learn: 1846.4001121	total: 1.03s	remaining: 3.45s
# 23:	learn: 1840.4678201	total: 1.08s	remaining: 3.42s
# 24:	learn: 1835.1901147	total: 1.12s	remaining: 3.36s
# 25:	learn: 1832.3973405	total: 1.16s	remaining: 3.31s
# 26:	learn: 1826.6093691	total: 1.2s	remaining: 3.25s
# 27:	learn: 1822.9582101	total: 1.24s	remaining: 3.2s
# 28:	learn: 1819.1568520	total: 1.29s	remaining: 3.15s
# 29:	learn: 1815.4362016	total: 1.33s	remaining: 3.1s
# 30:	learn: 1807.9072029	total: 1.37s	remaining: 3.06s
# 31:	learn: 1804.2259022	total: 1.41s	remaining: 2.99s
# 32:	learn: 1798.7842635	total: 1.45s	remaining: 2.94s
# 33:	learn: 1794.3380844	total: 1.49s	remaining: 2.9s
# 34:	learn: 1788.7103776	total: 1.54s	remaining: 2.87s
# 35:	learn: 1785.6203952	total: 1.59s	remaining: 2.82s
# 36:	learn: 1781.5278126	total: 1.63s	remaining: 2.77s
# 37:	learn: 1778.0720051	total: 1.67s	remaining: 2.72s
# 38:	learn: 1775.5885472	total: 1.71s	remaining: 2.67s
# 39:	learn: 1771.6141395	total: 1.75s	remaining: 2.62s
# 40:	learn: 1767.6683674	total: 1.8s	remaining: 2.59s
# 41:	learn: 1765.4567447	total: 1.84s	remaining: 2.54s
# 42:	learn: 1763.3855571	total: 1.88s	remaining: 2.49s
# 43:	learn: 1761.0504581	total: 1.91s	remaining: 2.44s
# 44:	learn: 1759.2657412	total: 1.95s	remaining: 2.38s
# 45:	learn: 1753.3410222	total: 2s	remaining: 2.35s
# 46:	learn: 1750.6179946	total: 2.04s	remaining: 2.31s
# 47:	learn: 1747.6976361	total: 2.09s	remaining: 2.26s
# 48:	learn: 1744.9182449	total: 2.13s	remaining: 2.22s
# 49:	learn: 1743.7462115	total: 2.18s	remaining: 2.18s
# 50:	learn: 1739.9660119	total: 2.23s	remaining: 2.14s
# 51:	learn: 1736.3293934	total: 2.28s	remaining: 2.1s
# 52:	learn: 1734.4059721	total: 2.32s	remaining: 2.06s
# 53:	learn: 1731.9279103	total: 2.37s	remaining: 2.02s
# 54:	learn: 1729.7162249	total: 2.42s	remaining: 1.98s
# 55:	learn: 1727.2955739	total: 2.47s	remaining: 1.94s
# 56:	learn: 1724.8814988	total: 2.52s	remaining: 1.9s
# 57:	learn: 1723.3432112	total: 2.56s	remaining: 1.86s
# 58:	learn: 1720.8367020	total: 2.61s	remaining: 1.81s
# 59:	learn: 1720.3465012	total: 2.65s	remaining: 1.76s
# 60:	learn: 1719.0940007	total: 2.69s	remaining: 1.72s
# 61:	learn: 1717.3937890	total: 2.73s	remaining: 1.68s
# 62:	learn: 1715.3503804	total: 2.77s	remaining: 1.63s
# 63:	learn: 1713.4184926	total: 2.82s	remaining: 1.58s
# 64:	learn: 1711.9964430	total: 2.86s	remaining: 1.54s
# 65:	learn: 1710.0483790	total: 2.9s	remaining: 1.49s
# 66:	learn: 1708.0501415	total: 2.94s	remaining: 1.45s
# 67:	learn: 1706.4670985	total: 2.99s	remaining: 1.41s
# 68:	learn: 1704.1938561	total: 3.03s	remaining: 1.36s
# 69:	learn: 1703.3412048	total: 3.08s	remaining: 1.32s
# 70:	learn: 1701.3986694	total: 3.12s	remaining: 1.27s
# 71:	learn: 1699.6775874	total: 3.16s	remaining: 1.23s
# 72:	learn: 1698.1670386	total: 3.2s	remaining: 1.18s
# 73:	learn: 1695.8552589	total: 3.25s	remaining: 1.14s
# 74:	learn: 1694.4482962	total: 3.3s	remaining: 1.1s
# 75:	learn: 1692.3646952	total: 3.34s	remaining: 1.05s
# 76:	learn: 1689.8176629	total: 3.39s	remaining: 1.01s
# 77:	learn: 1687.8181283	total: 3.43s	remaining: 969ms
# 78:	learn: 1685.5275786	total: 3.48s	remaining: 924ms
# 79:	learn: 1684.2300698	total: 3.51s	remaining: 879ms
# 80:	learn: 1682.4455816	total: 3.55s	remaining: 833ms
# 81:	learn: 1681.0696887	total: 3.59s	remaining: 789ms
# 82:	learn: 1679.3544239	total: 3.64s	remaining: 745ms
# 83:	learn: 1678.5452068	total: 3.69s	remaining: 702ms
# 84:	learn: 1676.9310288	total: 3.73s	remaining: 658ms
# 85:	learn: 1675.1137652	total: 3.78s	remaining: 615ms
# 86:	learn: 1674.1167565	total: 3.81s	remaining: 570ms
# 87:	learn: 1672.7817012	total: 3.86s	remaining: 526ms
# 88:	learn: 1671.8454356	total: 3.9s	remaining: 483ms
# 89:	learn: 1670.0975382	total: 3.95s	remaining: 439ms
# 90:	learn: 1667.6153538	total: 4s	remaining: 395ms
# 91:	learn: 1666.3145489	total: 4.04s	remaining: 351ms
# 92:	learn: 1665.3731348	total: 4.09s	remaining: 308ms
# 93:	learn: 1664.1797751	total: 4.13s	remaining: 264ms
# 94:	learn: 1663.4006779	total: 4.19s	remaining: 220ms
# 95:	learn: 1662.5843605	total: 4.23s	remaining: 176ms
# 96:	learn: 1660.9356596	total: 4.27s	remaining: 132ms
# 97:	learn: 1659.6563768	total: 4.31s	remaining: 88.1ms
# 98:	learn: 1655.9942987	total: 4.36s	remaining: 44.1ms
# 99:	learn: 1653.2550411	total: 4.41s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3288.6705949	total: 52.1ms	remaining: 5.16s
# 1:	learn: 2666.2516049	total: 102ms	remaining: 4.98s
# 2:	learn: 2402.3006903	total: 157ms	remaining: 5.06s
# 3:	learn: 2256.7628545	total: 202ms	remaining: 4.85s
# 4:	learn: 2176.7654791	total: 244ms	remaining: 4.63s
# 5:	learn: 2128.8121022	total: 287ms	remaining: 4.5s
# 6:	learn: 2075.6932689	total: 335ms	remaining: 4.45s
# 7:	learn: 2055.7567883	total: 372ms	remaining: 4.28s
# 8:	learn: 2037.2212986	total: 411ms	remaining: 4.16s
# 9:	learn: 2001.0521110	total: 453ms	remaining: 4.08s
# 10:	learn: 1982.2596172	total: 498ms	remaining: 4.03s
# 11:	learn: 1959.2969269	total: 543ms	remaining: 3.98s
# 12:	learn: 1935.6620588	total: 587ms	remaining: 3.93s
# 13:	learn: 1918.5409291	total: 630ms	remaining: 3.87s
# 14:	learn: 1909.6140843	total: 678ms	remaining: 3.84s
# 15:	learn: 1900.9763270	total: 722ms	remaining: 3.79s
# 16:	learn: 1890.4412417	total: 768ms	remaining: 3.75s
# 17:	learn: 1882.0441548	total: 810ms	remaining: 3.69s
# 18:	learn: 1874.4013104	total: 855ms	remaining: 3.65s
# 19:	learn: 1871.3335313	total: 891ms	remaining: 3.56s
# 20:	learn: 1863.0299154	total: 935ms	remaining: 3.52s
# 21:	learn: 1851.6516707	total: 981ms	remaining: 3.48s
# 22:	learn: 1840.7880071	total: 1.03s	remaining: 3.45s
# 23:	learn: 1835.6814098	total: 1.08s	remaining: 3.41s
# 24:	learn: 1832.2310209	total: 1.12s	remaining: 3.35s
# 25:	learn: 1828.2366455	total: 1.16s	remaining: 3.29s
# 26:	learn: 1821.8650547	total: 1.21s	remaining: 3.28s
# 27:	learn: 1815.1973116	total: 1.26s	remaining: 3.24s
# 28:	learn: 1810.8110329	total: 1.31s	remaining: 3.21s
# 29:	learn: 1809.6714576	total: 1.35s	remaining: 3.14s
# 30:	learn: 1803.4206103	total: 1.39s	remaining: 3.1s
# 31:	learn: 1797.0896523	total: 1.43s	remaining: 3.04s
# 32:	learn: 1793.4167678	total: 1.47s	remaining: 2.99s
# 33:	learn: 1790.6108884	total: 1.52s	remaining: 2.94s
# 34:	learn: 1786.9925375	total: 1.56s	remaining: 2.91s
# 35:	learn: 1781.5846078	total: 1.6s	remaining: 2.85s
# 36:	learn: 1776.9040459	total: 1.65s	remaining: 2.81s
# 37:	learn: 1773.7694647	total: 1.69s	remaining: 2.76s
# 38:	learn: 1771.6167354	total: 1.73s	remaining: 2.7s
# 39:	learn: 1768.9046849	total: 1.77s	remaining: 2.65s
# 40:	learn: 1764.9351205	total: 1.81s	remaining: 2.61s
# 41:	learn: 1761.3440603	total: 1.86s	remaining: 2.56s
# 42:	learn: 1757.6007760	total: 1.9s	remaining: 2.52s
# 43:	learn: 1755.9286633	total: 1.96s	remaining: 2.49s
# 44:	learn: 1754.8043116	total: 2s	remaining: 2.44s
# 45:	learn: 1752.7532355	total: 2.04s	remaining: 2.39s
# 46:	learn: 1748.8409324	total: 2.09s	remaining: 2.35s
# 47:	learn: 1745.4854164	total: 2.14s	remaining: 2.31s
# 48:	learn: 1742.7166383	total: 2.18s	remaining: 2.27s
# 49:	learn: 1741.1183242	total: 2.21s	remaining: 2.21s
# 50:	learn: 1736.6349978	total: 2.25s	remaining: 2.17s
# 51:	learn: 1734.2066239	total: 2.29s	remaining: 2.12s
# 52:	learn: 1731.9602652	total: 2.33s	remaining: 2.07s
# 53:	learn: 1729.1445346	total: 2.38s	remaining: 2.02s
# 54:	learn: 1727.2620651	total: 2.42s	remaining: 1.98s
# 55:	learn: 1724.8395411	total: 2.46s	remaining: 1.94s
# 56:	learn: 1723.7188604	total: 2.5s	remaining: 1.89s
# 57:	learn: 1721.6584415	total: 2.55s	remaining: 1.84s
# 58:	learn: 1719.3868267	total: 2.59s	remaining: 1.8s
# 59:	learn: 1717.5088805	total: 2.64s	remaining: 1.76s
# 60:	learn: 1714.7143768	total: 2.68s	remaining: 1.72s
# 61:	learn: 1713.0405280	total: 2.72s	remaining: 1.67s
# 62:	learn: 1711.1457814	total: 2.76s	remaining: 1.62s
# 63:	learn: 1709.2721279	total: 2.81s	remaining: 1.58s
# 64:	learn: 1708.3591165	total: 2.85s	remaining: 1.54s
# 65:	learn: 1705.8786367	total: 2.9s	remaining: 1.49s
# 66:	learn: 1704.2375629	total: 2.94s	remaining: 1.45s
# 67:	learn: 1702.2087344	total: 2.98s	remaining: 1.4s
# 68:	learn: 1701.1788533	total: 3.02s	remaining: 1.36s
# 69:	learn: 1699.2096702	total: 3.07s	remaining: 1.32s
# 70:	learn: 1697.6427662	total: 3.11s	remaining: 1.27s
# 71:	learn: 1696.1057369	total: 3.18s	remaining: 1.24s
# 72:	learn: 1694.5589939	total: 3.22s	remaining: 1.19s
# 73:	learn: 1693.1877068	total: 3.27s	remaining: 1.15s
# 74:	learn: 1691.5442165	total: 3.31s	remaining: 1.1s
# 75:	learn: 1690.3288421	total: 3.35s	remaining: 1.06s
# 76:	learn: 1688.1717922	total: 3.4s	remaining: 1.02s
# 77:	learn: 1686.8526320	total: 3.48s	remaining: 980ms
# 78:	learn: 1685.4006052	total: 3.54s	remaining: 942ms
# 79:	learn: 1683.9502592	total: 3.6s	remaining: 900ms
# 80:	learn: 1682.5946508	total: 3.65s	remaining: 856ms
# 81:	learn: 1681.1960064	total: 3.69s	remaining: 810ms
# 82:	learn: 1679.6739119	total: 3.73s	remaining: 765ms
# 83:	learn: 1678.9501343	total: 3.77s	remaining: 718ms
# 84:	learn: 1677.3714332	total: 3.81s	remaining: 673ms
# 85:	learn: 1675.5745099	total: 3.85s	remaining: 627ms
# 86:	learn: 1674.4087504	total: 3.9s	remaining: 582ms
# 87:	learn: 1672.6249749	total: 3.94s	remaining: 538ms
# 88:	learn: 1671.4947299	total: 3.99s	remaining: 493ms
# 89:	learn: 1670.3111946	total: 4.03s	remaining: 448ms
# 90:	learn: 1669.0360813	total: 4.07s	remaining: 402ms
# 91:	learn: 1668.2797565	total: 4.1s	remaining: 357ms
# 92:	learn: 1667.6874382	total: 4.14s	remaining: 312ms
# 93:	learn: 1666.2529113	total: 4.18s	remaining: 267ms
# 94:	learn: 1665.0009239	total: 4.22s	remaining: 222ms
# 95:	learn: 1664.3491851	total: 4.26s	remaining: 178ms
# 96:	learn: 1661.1436715	total: 4.33s	remaining: 134ms
# 97:	learn: 1660.0151983	total: 4.37s	remaining: 89.3ms
# 98:	learn: 1659.2186404	total: 4.41s	remaining: 44.5ms
# 99:	learn: 1658.3242999	total: 4.45s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3299.0819180	total: 42ms	remaining: 4.16s
# 1:	learn: 2663.6707359	total: 85.7ms	remaining: 4.2s
# 2:	learn: 2399.7324671	total: 131ms	remaining: 4.24s
# 3:	learn: 2266.4951556	total: 175ms	remaining: 4.21s
# 4:	learn: 2194.6877552	total: 220ms	remaining: 4.19s
# 5:	learn: 2139.2829959	total: 264ms	remaining: 4.13s
# 6:	learn: 2084.6238966	total: 315ms	remaining: 4.19s
# 7:	learn: 2058.0497515	total: 350ms	remaining: 4.03s
# 8:	learn: 2019.4942744	total: 394ms	remaining: 3.98s
# 9:	learn: 2002.8439566	total: 439ms	remaining: 3.95s
# 10:	learn: 1983.8004135	total: 478ms	remaining: 3.86s
# 11:	learn: 1968.9043186	total: 517ms	remaining: 3.79s
# 12:	learn: 1947.3582749	total: 566ms	remaining: 3.79s
# 13:	learn: 1936.3148185	total: 617ms	remaining: 3.79s
# 14:	learn: 1929.0294518	total: 668ms	remaining: 3.79s
# 15:	learn: 1918.6765598	total: 709ms	remaining: 3.72s
# 16:	learn: 1911.1853077	total: 751ms	remaining: 3.67s
# 17:	learn: 1905.8578141	total: 794ms	remaining: 3.62s
# 18:	learn: 1895.0235311	total: 843ms	remaining: 3.6s
# 19:	learn: 1882.1282749	total: 903ms	remaining: 3.61s
# 20:	learn: 1872.1331552	total: 959ms	remaining: 3.61s
# 21:	learn: 1866.4277402	total: 1.01s	remaining: 3.59s
# 22:	learn: 1859.8222946	total: 1.07s	remaining: 3.57s
# 23:	learn: 1854.3523136	total: 1.12s	remaining: 3.54s
# 24:	learn: 1846.3456024	total: 1.15s	remaining: 3.46s
# 25:	learn: 1835.4135931	total: 1.2s	remaining: 3.42s
# 26:	learn: 1830.2796761	total: 1.24s	remaining: 3.36s
# 27:	learn: 1822.6434433	total: 1.29s	remaining: 3.32s
# 28:	learn: 1817.5910217	total: 1.33s	remaining: 3.26s
# 29:	learn: 1812.2892866	total: 1.38s	remaining: 3.21s
# 30:	learn: 1808.4259707	total: 1.41s	remaining: 3.15s
# 31:	learn: 1803.8198216	total: 1.45s	remaining: 3.09s
# 32:	learn: 1796.6332656	total: 1.51s	remaining: 3.06s
# 33:	learn: 1791.9353144	total: 1.54s	remaining: 3s
# 34:	learn: 1788.2086843	total: 1.58s	remaining: 2.94s
# 35:	learn: 1786.3660196	total: 1.62s	remaining: 2.88s
# 36:	learn: 1782.4074869	total: 1.66s	remaining: 2.83s
# 37:	learn: 1779.3181749	total: 1.71s	remaining: 2.8s
# 38:	learn: 1774.9472068	total: 1.76s	remaining: 2.75s
# 39:	learn: 1771.9160657	total: 1.81s	remaining: 2.71s
# 40:	learn: 1769.5423524	total: 1.84s	remaining: 2.65s
# 41:	learn: 1765.3899386	total: 1.89s	remaining: 2.61s
# 42:	learn: 1762.7085874	total: 1.93s	remaining: 2.56s
# 43:	learn: 1759.7040705	total: 1.97s	remaining: 2.51s
# 44:	learn: 1756.2852645	total: 2.02s	remaining: 2.47s
# 45:	learn: 1754.0497345	total: 2.06s	remaining: 2.42s
# 46:	learn: 1751.6422562	total: 2.1s	remaining: 2.36s
# 47:	learn: 1748.7930446	total: 2.13s	remaining: 2.31s
# 48:	learn: 1746.5738976	total: 2.18s	remaining: 2.27s
# 49:	learn: 1744.0628083	total: 2.22s	remaining: 2.22s
# 50:	learn: 1741.5538310	total: 2.26s	remaining: 2.17s
# 51:	learn: 1738.3479994	total: 2.31s	remaining: 2.13s
# 52:	learn: 1736.1421303	total: 2.35s	remaining: 2.08s
# 53:	learn: 1733.9147618	total: 2.4s	remaining: 2.04s
# 54:	learn: 1731.8967258	total: 2.44s	remaining: 2s
# 55:	learn: 1730.0933694	total: 2.48s	remaining: 1.95s
# 56:	learn: 1728.9355475	total: 2.52s	remaining: 1.9s
# 57:	learn: 1726.9800950	total: 2.56s	remaining: 1.85s
# 58:	learn: 1723.6036660	total: 2.61s	remaining: 1.81s
# 59:	learn: 1721.4969599	total: 2.65s	remaining: 1.77s
# 60:	learn: 1719.4061209	total: 2.7s	remaining: 1.72s
# 61:	learn: 1716.3133387	total: 2.74s	remaining: 1.68s
# 62:	learn: 1714.5779917	total: 2.79s	remaining: 1.64s
# 63:	learn: 1712.6385996	total: 2.83s	remaining: 1.59s
# 64:	learn: 1710.9956772	total: 2.87s	remaining: 1.54s
# 65:	learn: 1708.2363742	total: 2.91s	remaining: 1.5s
# 66:	learn: 1706.0492579	total: 2.96s	remaining: 1.46s
# 67:	learn: 1704.7815779	total: 3s	remaining: 1.41s
# 68:	learn: 1702.4127985	total: 3.04s	remaining: 1.36s
# 69:	learn: 1700.2465997	total: 3.08s	remaining: 1.32s
# 70:	learn: 1698.6237822	total: 3.13s	remaining: 1.28s
# 71:	learn: 1698.0590136	total: 3.17s	remaining: 1.23s
# 72:	learn: 1697.4674563	total: 3.21s	remaining: 1.19s
# 73:	learn: 1696.0330777	total: 3.25s	remaining: 1.14s
# 74:	learn: 1694.5414216	total: 3.3s	remaining: 1.1s
# 75:	learn: 1692.5260813	total: 3.33s	remaining: 1.05s
# 76:	learn: 1691.2079931	total: 3.38s	remaining: 1.01s
# 77:	learn: 1689.8189182	total: 3.42s	remaining: 966ms
# 78:	learn: 1688.3666368	total: 3.46s	remaining: 921ms
# 79:	learn: 1685.9757333	total: 3.51s	remaining: 877ms
# 80:	learn: 1684.7234568	total: 3.54s	remaining: 832ms
# 81:	learn: 1682.6507859	total: 3.58s	remaining: 786ms
# 82:	learn: 1681.2711552	total: 3.62s	remaining: 742ms
# 83:	learn: 1679.8915686	total: 3.67s	remaining: 698ms
# 84:	learn: 1678.0072896	total: 3.71s	remaining: 655ms
# 85:	learn: 1675.7858327	total: 3.75s	remaining: 610ms
# 86:	learn: 1673.8926819	total: 3.79s	remaining: 567ms
# 87:	learn: 1672.4528706	total: 3.83s	remaining: 522ms
# 88:	learn: 1670.4059804	total: 3.88s	remaining: 479ms
# 89:	learn: 1669.0933061	total: 3.92s	remaining: 436ms
# 90:	learn: 1667.2689101	total: 3.97s	remaining: 392ms
# 91:	learn: 1665.9629998	total: 4.01s	remaining: 349ms
# 92:	learn: 1664.9888050	total: 4.05s	remaining: 305ms
# 93:	learn: 1664.1059962	total: 4.09s	remaining: 261ms
# 94:	learn: 1663.3468006	total: 4.13s	remaining: 217ms
# 95:	learn: 1661.8808443	total: 4.18s	remaining: 174ms
# 96:	learn: 1660.8807367	total: 4.21s	remaining: 130ms
# 97:	learn: 1659.9073141	total: 4.26s	remaining: 86.9ms
# 98:	learn: 1659.1464365	total: 4.3s	remaining: 43.4ms
# 99:	learn: 1658.5165551	total: 4.33s	remaining: 0us
# Average CatBoost evaluation score: 0.8689940875608567
# CPU times: user 22.9 s, sys: 111 ms, total: 23 s
# Wall time: 23.8 s

# %% [markdown]
# ## Model analysis

# %% [markdown]
# Linear Regression: Compared to the other models, the RMSE value is relatively high, indicating a poorer performance.

# %% [markdown]
# SGD Linear Regression: A similar performance to Linear Regression, but significantly slower due to the stochastic gradient descent.

# %% [markdown]
# Random Forest Regression: Lowest RMSE compared to the other models, indicating a better performance, but still slow due to the ensemble nature of Random Forest.

# %% [markdown]
# Decision Tree Regression: Higher RMSE than Random Forest, but better than Linear Regression and SGD. The model is faster than the Random Forest and SGD models.

# %% [markdown]
# XGBoost Regressor: Similar performance to the Random Forest model with a faster training time.

# %% [markdown]
# LightGBM: Slightly higher RMSE compared to XGBoost but a bit faster with training.

# %% [markdown]
# CatBoost: Similar performance to XGBoost and LightGBM with a faster training time.

# %% [markdown]
# In summary, Random Forest Regression, XGBoost, LightGBM, and CatBoost perform relatively well in terms of both speed and quality compared to other models. Any one of those models would be a good choice for developing the app. Linear Regression and SGD Linear Regression have poorer performance in terms of quality, while Decision Tree Regression has a higher RMSE and slower training time compared to other tree-based models. With Cross-Validation on the better performing models, Random Forest and CatBoost, it appears that Random Forest came out on top purely looking at the evaluation score. However, based on time, CatBoost might prove to be a better model, since it is very close to the Random Forest evaluation score and much quicker.
